# %%
import sqlite3

# %% [markdown]
# ### Write a sql query to get books that has rate >=3 and has 'Mr' in its name

# %%
conection = sqlite3.connect('Books.db')
sql = 'select * from Books where Rate >= ? and Title like ?'
Data = [3, '%Mr%']
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(48, 'Mrs. Houdini', 30.25, 5, 3),
#  (243, 'My Mrs. Brown', 24.48, 3, 9),
#  (248, 'Dear Mr. Knightley', 11.21, 5, 9)]

# %% [markdown]
# ### Write a sql query to get books that has rate >=3 or price > 20

# %%
conection = sqlite3.connect('Books.db')
sql = 'select * from Books where Price > ? or Rate >= ? '
Data = [20, 3]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(1, "It's Only the Himalayas", 45.17, 2, 1),
#  (2,
#   'Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',
#   49.43,
#   4,
#   1),
#  (3,
#   'See America: A Celebration of Our National Parks & Treasured Sites',
#   48.87,
#   3,
#   1),
#  (4,
#   'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   36.94,
#   2,
#   1),
#  (5, 'Under the Tuscan Sun', 37.33, 3, 1),
#  (6, 'A Summer In Europe', 44.34, 2, 1),
#  (7, 'The Great Railway Bazaar', 30.54, 1, 1),
#  (8, 'A Year in Provence (Provence #1)', 56.88, 4, 1),
#  (9,
#   'The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',
#   23.21,
#   1,
#   1),
#  (10, 'Neither Here nor There: Travels in Europe', 38.95, 3, 1),
#  (11, '1,000 Places to See Before You Die', 26.08, 5, 1),
#  (12, 'Sharp Objects', 47.82, 4, 2),
#  (14, 'The Past Never Ends', 56.5, 4, 2),
#  (16, 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 44.1, 4, 2),
# ...

# %% [markdown]
# ### Write a sql query to get books that has rate not 3

# %%
conection = sqlite3.connect('Books.db')
sql = 'select * from Books where Rate != ? '
Data = [3]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(1, "It's Only the Himalayas", 45.17, 2, 1),
#  (2,
#   'Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',
#   49.43,
#   4,
#   1),
#  (4,
#   'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   36.94,
#   2,
#   1),
#  (6, 'A Summer In Europe', 44.34, 2, 1),
#  (7, 'The Great Railway Bazaar', 30.54, 1, 1),
#  (8, 'A Year in Provence (Provence #1)', 56.88, 4, 1),
#  (9,
#   'The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',
#   23.21,
#   1,
#   1),
#  (11, '1,000 Places to See Before You Die', 26.08, 5, 1),
#  (12, 'Sharp Objects', 47.82, 4, 2),
#  (13, 'In a Dark, Dark Wood', 19.63, 1, 2),
#  (14, 'The Past Never Ends', 56.5, 4, 2),
#  (15, 'A Murder in Time', 16.64, 1, 2),
#  (16, 'The Murder of Roger Ackroyd (Hercule Poirot #4)', 44.1, 4, 2),
#  (17, 'The Last Mile (Amos Decker #2)', 54.21, 2, 2),
#  (18, 'That Darkness (Gardiner and Renner #1)', 13.92, 1, 2),
# ...

# %% [markdown]
# ### Write a sql query to get books that has price between 10 and 40 and has rate 3 or 4 or 1

# %%
conection = sqlite3.connect('Books.db')
sql = '''select * from Books where Rate = ? or Rate = ? or Rate =  ? 
         and Price between ? and ?'''
Data = [1,3,4,10,40]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(3,
#   'See America: A Celebration of Our National Parks & Treasured Sites',
#   48.87,
#   3,
#   1),
#  (5, 'Under the Tuscan Sun', 37.33, 3, 1),
#  (7, 'The Great Railway Bazaar', 30.54, 1, 1),
#  (9,
#   'The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',
#   23.21,
#   1,
#   1),
#  (10, 'Neither Here nor There: Travels in Europe', 38.95, 3, 1),
#  (13, 'In a Dark, Dark Wood', 19.63, 1, 2),
#  (15, 'A Murder in Time', 16.64, 1, 2),
#  (18, 'That Darkness (Gardiner and Renner #1)', 13.92, 1, 2),
#  (19, 'Tastes Like Fear (DI Marnie Rome #3)', 10.69, 1, 2),
#  (22, 'Poisonous (Max Revere Novels #3)', 26.8, 3, 2),
#  (24, 'Most Wanted', 35.28, 3, 2),
#  (25, 'Hide Away (Eve Duncan #20)', 11.84, 1, 2),
#  (26, 'Boar Island (Anna Pigeon #19)', 59.48, 3, 2),
#  (28, 'Playing with Fire', 13.71, 3, 2),
#  (31, 'Delivering the Truth (Quaker Midwife Mystery #1)', 20.89, 4, 2),
# ...

# %% [markdown]
# ### Write a sql query to get the top 5 most expensive books (order books desc with price column and then limit the result to the first 5)

# %%
conection = sqlite3.connect('Books.db')
sql = 'select * from Books order by Price desc limit ?'
Data = [5]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(192, 'The Perfect Play (Play by Play #1)', 59.99, 3, 7),
#  (272, 'Last One Home (New Beginnings #1)', 59.98, 3, 9),
#  (846, 'Civilization and Its Discontents', 59.95, 2, 25),
#  (926, 'The Barefoot Contessa Cookbook', 59.92, 5, 32),
#  (369, 'The Diary of a Young Girl', 59.9, 3, 12)]

# %% [markdown]
# ### Write a sql query to get the 3rd 10 books in the books table order first by rate desc and then by price asc

# %%
conection = sqlite3.connect('Books.db')
sql = 'select * from Books order by Rate desc, Price limit ?'
Data = [10]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(782, 'An Abundance of Katherines', 10.0, 5, 20),
#  (498, 'Greek Mythic History', 10.23, 5, 14),
#  (928,
#   'The Power Greens Cookbook: 140 Delicious Superfood Recipes',
#   11.05,
#   5,
#   32),
#  (248, 'Dear Mr. Knightley', 11.21, 5, 9),
#  (777, 'The Darkest Corners', 11.33, 5, 20),
#  (923,
#   'Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based Recipes--All Under 300 Calories',
#   11.38,
#   5,
#   32),
#  (129, 'Fruits Basket, Vol. 2 (Fruits Basket #2)', 11.64, 5, 4),
#  (860, 'Old School (Diary of a Wimpy Kid #10)', 11.83, 5, 29),
#  (98,
#   'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)',
#   11.89,
#   5,
#   4),
#  (711, 'Every Heart a Doorway (Every Heart A Doorway #1)', 12.16, 5, 18)]

# %% [markdown]
# ### Write a sql query to add a new category in categories table and add 5 books to this category in books table with title, rate and price

# %%
conection = sqlite3.connect('Books.db')
sql = 'insert into Gategories (GategoryName) values (?)'
Data = ['Technology']
rows1 = conection.execute(sql,Data)
conection.commit()
conection.close()

q = rows1.lastrowid

Books = [["Delete",18.69,5,q],
        ["Deviced!: Balancing Life and Technology in a Digital World ",30, 4,q],
        ["The Truth About Your Future", 18.9, 4,q],
        ["Digital Leadership: Changing Paradigms for Changing Times", 21.71, 4,q],
        ["How to Be Good at Science, Technology, and Engineering ",42.73, 3,q]]

for Book in Books:

    conection = sqlite3.connect('Books.db')        
    sql = 'insert into Books (Title,Price,Rate,GategoryId) values (?, ?, ?, ?)'
    Data = Book
    rows = conection.execute(sql,Data)
    conection.commit()
    conection.close()

# %% [markdown]
# ### Write a sql query to update book's rate to 3 that thier price < 20£

# %%
conection = sqlite3.connect('Books.db')
sql = 'update Books set Rate = ? where Price < ?'
Data = [3,20]
rows = conection.execute(sql, Data)
conection.commit()
conection.close()
rows

# %% [markdown]
# ### Write a sql query to delete all books that have price > 50£ and has rate <= 2

# %%
conection = sqlite3.connect('Books.db')
sql = 'delete from Books where Price > ? and Rate <= ?'
Data = [50,2]
conection.execute(sql, Data)
conection.commit()
conection.close()
rows

# %% [markdown]
# ### Write a sql query to count the number of books that have 'Secret' in thier names and price between 10£ and 25£

# %%
conection = sqlite3.connect('Books.db')
sql = "select count(Title) from Books where Title like ? AND price BETWEEN ? and ?"
Data = ["%Secret%", 10, 25]
rows = conection.execute(sql, Data).fetchall()
conection.close()
rows
# Out:
# [(5,)]

# %% [markdown]
# ### Write a sql query to get the minimum & maximum price for all the books that have rate 5

# %%
conection = sqlite3.connect('Books.db')
sql = '''select * from Books where Rate = ? and Price = (select min(Price) from Books where Rate = ?) union
         select * from Books where Rate = ? and Price = (select max(Price) from Books where Rate = ?)'''
Data = [5,5,5,5]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(447, 'No One Here Gets Out Alive', 20.02, 5, 13),
#  (926, 'The Barefoot Contessa Cookbook', 59.92, 5, 32)]

# %% [markdown]
# ### Write a sql query to calculate the avg price for all the books that have rate 5

# %%
conection = sqlite3.connect('Books.db')
sql = 'select avg(Price) from Books where Rate = ? '
Data = [5]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(41.05000000000002,)]

# %% [markdown]
# ### Write a sql query to sum all book's price that have rate 2 and price between 10 and 40

# %%
conection = sqlite3.connect('Books.db')
sql = 'select sum(Price) from Books where Rate = ? order by Price AND price BETWEEN ? and ?'
Data = [2,10,40]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(4439.469999999999,)]

# %% [markdown]
# ### Write a sql query to join both books & categories table into one new table containing book_name & category_name & book_rate and book_price

# %%
conection = sqlite3.connect('Books.db')
sql = 'select Books.Title, Gategories.Gategoryname, Books.Rate, Books.Price from Books inner join Gategories on Books.GategoryId = Gategories.GategoryId'
Data = []
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [("It's Only the Himalayas", 'Travel', 2, 45.17),
#  ('Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',
#   'Travel',
#   4,
#   49.43),
#  ('See America: A Celebration of Our National Parks & Treasured Sites',
#   'Travel',
#   3,
#   48.87),
#  ('Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel',
#   'Travel',
#   2,
#   36.94),
#  ('Under the Tuscan Sun', 'Travel', 3, 37.33),
#  ('A Summer In Europe', 'Travel', 2, 44.34),
#  ('The Great Railway Bazaar', 'Travel', 1, 30.54),
#  ('A Year in Provence (Provence #1)', 'Travel', 4, 56.88),
#  ('The Road to Little Dribbling: Adventures of an American in Britain (Notes From a Small Island #2)',
#   'Travel',
#   1,
#   23.21),
#  ('Neither Here nor There: Travels in Europe', 'Travel', 3, 38.95),
#  ('1,000 Places to See Before You Die', 'Travel', 5, 26.08),
#  ('Sharp Objects', 'Mystery', 4, 47.82),
#  ('In a Dark, Dark Wood', 'Mystery', 3, 19.63),
# ...

# %% [markdown]
# ### Write a sql query to calculate how many books each rate has and have price between 20£ and 30£

# %%
conection = sqlite3.connect('Books.db')
sql = ' select count(Rate), Rate from Books where Price between ? and ? group by Rate '
Data = [20,30]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(56, 1), (40, 2), (41, 3), (36, 4), (36, 5)]

# %% [markdown]
# ### Write a sql query to calculate how many books each category has having count > 10

# %%
conection = sqlite3.connect('Books.db')
sql = ''' select Books.GategoryId, Gategories.GategoryName, count(Books.GategoryId) from Books inner join Gategories
          on Books.gategoryId = Gategories.gategoryId 
          group by Books.GategoryId having count(Books.GategoryId) > ? '''
Data = [10]
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [(1, 'Travel', 11),
#  (2, 'Mystery', 30),
#  (3, 'Historical Fiction', 24),
#  (4, 'Sequential Art', 70),
#  (5, 'Classics', 17),
#  (7, 'Romance', 33),
#  (8, 'Womens Fiction', 16),
#  (9, 'Fiction', 60),
#  (10, 'Childrens', 28),
#  (12, 'Nonfiction', 104),
#  (13, 'Music', 11),
#  (14, 'Default', 144),
#  (15, 'Science Fiction', 14),
#  (17, 'Add a comment', 60),
#  (18, 'Fantasy', 40),
#  (20, 'Young Adult', 50),
#  (21, 'Science', 13),
#  (22, 'Poetry', 18),
#  (30, 'Horror', 15),
#  (31, 'History', 16),
#  (32, 'Food and Drink', 28),
#  (34, 'Business', 11),
#  (36, 'Thriller', 11)]

# %% [markdown]
# ###  Write a sql query to get all books with category_name='Music' using subquery

# %%
conection = sqlite3.connect('Books.db')
sql = ''' select Books.Title, Books.Price, Books.Rate, Gategories.GategoryName from Books inner join Gategories
          on Books.gategoryId = Gategories.gategoryId
          where Gategories.GategoryId in (select Gategories.GategoryId from Gategories where GategoryName like ?)'''
Data = ['%Music%']
rows = conection.execute(sql,Data).fetchall()
conection.close()
rows
# Out:
# [('Rip it Up and Start Again', 35.02, 5, 'Music'),
#  ('Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   57.25,
#   3,
#   'Music'),
#  ('How Music Works', 37.32, 2, 'Music'),
#  ('Love Is a Mix Tape (Music #1)', 18.03, 3, 'Music'),
#  ('Please Kill Me: The Uncensored Oral History of Punk', 31.19, 4, 'Music'),
#  ("Kill 'Em and Leave: Searching for James Brown and the American Soul",
#   45.05,
#   5,
#   'Music'),
#  ('This Is Your Brain on Music: The Science of a Human Obsession',
#   38.4,
#   1,
#   'Music'),
#  ('Orchestra of Exiles: The Story of Bronislaw Huberman, the Israel Philharmonic, and the One Thousand Jews He Saved from Nazi Horrors',
#   12.36,
#   3,
#   'Music'),
#  ('No One Here Gets Out Alive', 20.02, 5, 'Music'),
#  ('Life', 31.58, 5, 'Music'),
#  ('Forever Rockers (The Rocker #12)', 28.8, 3, 'Music')]

# %% [markdown]
# ### Export Database to CSV File and use pandas to read this CSV

# %%
import pandas as pd

# %%
df = pd.read_csv('Books.csv')

# %%
df
# Out:
#        Id                                              Title  Price  Rate  \
# 0       1                            It's Only the Himalayas  45.17     2
# 1       2  Full Moon over Noahâs Ark: An Odyssey to Mou...  49.43     4
# 2       3  See America: A Celebration of Our National Par...  48.87     3
# 3       4  Vagabonding: An Uncommon Guide to the Art of L...  36.94     2
# 4       5                               Under the Tuscan Sun  37.33     3
# ..    ...                                                ...    ...   ...
# 926  1001                                             Delete  18.69     3
# 927  1002  Deviced!: Balancing Life and Technology in a D...  30.00     4
# 928  1003                        The Truth About Your Future  18.90     3
# 929  1004  Digital Leadership: Changing Paradigms for Cha...  21.71     4
# 930  1005  How to Be Good at Science, Technology, and Eng...  42.73     3
#
#      GategoryId
# 0             1
# 1             1
# 2             1
# ...
